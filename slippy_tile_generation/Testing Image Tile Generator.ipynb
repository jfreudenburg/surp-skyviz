# %%
import numpy as np
from make_tileset_from_images import make_tileset_from_images

# %%
imdir = "sample_tiles"
imdict = {
    2: "rawim/taqi-al-din.jpg",
    4: "rawim/ireland.jpg"
}

# %%
make_tileset_from_images(imdir, imdict)
# Out:
# Writing Image Tiles to: sample_tiles
# Images defined for the following zoom levels: [2, 4]
# Generating Slices for Zoom Level 0
# Number of Slices/Pixels in each dimension 1 slices/256 px
# 	Generating tile (0, 0)
# Generating Slices for Zoom Level 1
# Number of Slices/Pixels in each dimension 2 slices/512 px
# 	Generating tile (0, 0)
# 	Generating tile (0, 1)
# 	Generating tile (1, 0)
# 	Generating tile (1, 1)
# Generating Slices for Zoom Level 2
# Number of Slices/Pixels in each dimension 4 slices/1024 px
# 	Generating tile (0, 0)
# 	Generating tile (0, 1)
# 	Generating tile (0, 2)
# 	Generating tile (0, 3)
# 	Generating tile (1, 0)
# 	Generating tile (1, 1)
# 	Generating tile (1, 2)
# 	Generating tile (1, 3)
# 	Generating tile (2, 0)
# 	Generating tile (2, 1)
# 	Generating tile (2, 2)
# 	Generating tile (2, 3)
# 	Generating tile (3, 0)
# 	Generating tile (3, 1)
# 	Generating tile (3, 2)
# 	Generating tile (3, 3)
# Generating Slices for Zoom Level 3
# ...

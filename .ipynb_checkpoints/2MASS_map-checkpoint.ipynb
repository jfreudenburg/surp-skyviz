# %%
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy.constants import c
#from astropy_healpix.core import boundaries_lonlat
from astropy.coordinates import Galactic

import numpy as np
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import PIL
from mycmap import get_continuous_cmap

# %% [markdown]
# # Some color scale options

# %%
mauve = get_continuous_cmap(['1E252A','2A323A','373D4A','434859','505168','5E5D78','6F6A86','817795','9188A3','A19AB0','B0ABBE','C1BCCB'])
bluegreen = get_continuous_cmap(['#083428', '#0d4237', '#125146', '#186156', '#1d7167', '#238178', '#2a918a', '#39a297', '#55b39b', '#72c3a0', '#90d2a4', '#afe1a9'])
purples = get_continuous_cmap(['18133A','271845','391D4F','4E225A','642764','6E2C5F','824678','956090','A87BA6','BA96BB','CBB1CD','DCCDDF'])
sunset = get_continuous_cmap(['#221155', '#412156', '#593256', '#704356', '#865655', '#9b6a54', '#af7e51', '#c3934e', '#d6a949', '#e8c043', '#f7d83b', '#fff332'])
hotpink = get_continuous_cmap(['150070','320085','550099','7D00AD','A900C2','D602D6','EB07C9','FA0CB3','FB25CA','FD3EDD','FE57ED','FF70FA','FB8AFF','F6A4FF','F5BEFF'])
lf = get_continuous_cmap(['#010052', '#27015d', '#410066', '#59016f', '#700575', '#870e79', '#9e187b', '#b42479', '#ca3273', '#de4166', '#f0534e', '#fc6a13'])

# %% [markdown]
# # Configuration

# %%
nside = 64 # set resolution scale (good to use a power of 2)
smoothing_scale = 0.7 # smoothing scale in degrees
zmin = 0.0 # minimum redshift
zmax = 0.2 # maximum redshift
fname = '2MRS_map_all'
cmap = get_continuous_cmap(['#221f5d', '#293367', '#2f4772', '#365b7c', '#3d6f86', '#438491', '#4a999b', '#51aea6', '#60c3b4', '#85d4c9', '#aae5dd', '#cef6f1'])

print('resolution: {:0.2f} deg'.format(np.degrees(hp.nside2resol(nside))))
print('number of pixels: {:d}'.format(hp.nside2npix(nside)))
# Out:
# resolution: 0.92 deg
# number of pixels: 49152

# %%
def cat2hpx(lon, lat, nside, radec=True):
    """
    Convert a catalogue to a HEALPix map of number counts per resolution
    element.

    Parameters
    ----------
    lon, lat : (ndarray, ndarray)
        Coordinates of the sources in degree. If radec=True, assume input is in the icrs
        coordinate system. Otherwise assume input is glon, glat

    nside : int
        HEALPix nside of the target map

    radec : bool
        Switch between R.A./Dec and glon/glat as input coordinate system.

    Return
    ------
    hpx_map : ndarray
        HEALPix map of the catalogue number counts in Galactic coordinates

    """

    npix = hp.nside2npix(nside)

    if radec:
        eq = SkyCoord(lon, lat, frame='icrs', unit='deg')
        l, b = eq.galactic.l.value, eq.galactic.b.value
    else:
        l, b = lon, lat

    # conver to theta, phi
    theta = np.radians(90. - b)
    phi = np.radians(l)

    # convert to HEALPix indices
    indices = hp.ang2pix(nside, theta, phi)

    idx, counts = np.unique(indices, return_counts=True)

    # fill the fullsky map
    hpx_map = np.zeros(npix, dtype=int)
    hpx_map[idx] = counts

    return hpx_map

# %% [markdown]
# # Load 2MASS Redshift Survey data

# %%
hdu = fits.open('2MASS_catalogs/catalog/2mrs_1175_done.fits')
cat = hdu[1].data

# %% [markdown]
# ## Redshift distribution plot

# %%
_=plt.hist(cat['V']/c.to('km/s').value,50)

# %% [markdown]
# # Create map

# %%
pixarea = hp.nside2pixarea(nside,degrees=True)
zvals = cat['V']/c.to('km/s').value
zcond = np.logical_and(zvals>=zmin, zvals<zmax)
catmap = cat2hpx(cat['GLON'][zcond],cat['GLAT'][zcond],nside)/pixarea
catmap_smoothed = hp.smoothing(catmap, fwhm=np.radians(smoothing_scale))

# %% [markdown]
# # Generate visualization

# %%
hp.mollview(
    catmap_smoothed,
    coord=["G","C"],
    unit='count/deg^2',
    title="2MASS Redshift Survey Galaxies ({:0.2f}<z<{:0.2f}, smoothing={:0.2f} deg)".format(zmin,zmax,smoothing_scale),
    norm="hist",
    min=0,
    max=60,
    cmap = mauve
)
hp.graticule(color='white')

hp.mollview(
    catmap,
    coord=["G","C"],
    unit='count/deg^2',
    title="2MASS Redshift Survey Galaxies ({:0.2f}<z<{:0.2f}), no smoothing)".format(zmin,zmax),
    norm="hist",
    min=0,
    max=60,
    cmap = mauve
)
hp.graticule(color='white')
plt.savefig(fname+'_moll.pdf',format='pdf')
# Out:
# 0.0 180.0 -180.0 180.0
# 0.0 180.0 -180.0 180.0

# %%
hp.orthview(
    catmap_smoothed,
    rot=(0,90),
    xsize=10000,
    #unit='count/deg^2',
    #title="2MASS Redshift Survey Galaxies ({:0.2f}<z<{:0.2f}, smoothing={:0.2f} deg)".format(zmin,zmax,smoothing_scale),
    title=None,
    norm="hist",
    #min=0,
    #max=60,
    cmap=bluegreen,
    cbar=False,
    margins=(0,0,0,0)
)
#hp.graticule(color='yellow')
plt.savefig(fname+'_smoothed_TEST.png',format='png')

# %% [markdown]
# # Test map

# %% [markdown]
# Mess around w/ the lat/lon values to build intuition about where these fall in an orthographic projection

# %%
lon = 215
lat = -45

# %%
print('lat: {:0.2f} \nlon: {:0.2f}'.format(lat,lon))

ns = 16
test_map = np.arange(hp.nside2npix(ns))

ipix = hp.ang2pix(ns,np.pi/2-np.pi*lat/180,np.pi*lon/180)
test_map[ipix] = 1.5*test_map.max()

hp.orthview(
    test_map,
    title = 'Centers: North pole (lon=0,lat=90) / South pole (lon=0,lat=-90)',
    rot=(0,90),
    unit="healpix index")
hp.graticule()
plt.savefig('ortho_test_1.png',format='png')

hp.orthview(
    test_map,
    title = 'Centers: (lon=0,lat=0) / (lon=180,lat=0)',
    rot=(0,0),
    unit="healpix index")
hp.graticule()
plt.savefig('ortho_test_2.png',format='png')

image = hp.orthview(
    test_map,
    title = 'Centers: (lon=45,lat=45) / (lon=215,lat=-45)',
    rot=(45,45),
    unit="healpix index",
    return_projected_map=True)
hp.graticule()
plt.savefig('ortho_test_3.png',format='png')
# Out:
# 0.0 180.0 -180.0 180.0
# lat: -45.00
# lon: 215.00
# 0.0 180.0 -180.0 180.0
# 0.0 180.0 -180.0 180.0

# %%
size = image.shape[0]
vmin = 0
vmax = np.max(image)

fig,axis = plt.subplots(1,1)
axis.imshow(image[:,:size],vmin=vmin,vmax=vmax)
plt.axis("off")
plt.savefig('figtest.png',format='png')

# %%
size = image.shape[0]
vmin = 0
vmax = np.max(image)

fig,axis = plt.subplots(1,1)
axis.imshow(image[:,size:],vmin=vmin,vmax=vmax)
plt.axis("off")
plt.savefig('figtest.png',format='png')

# %%
plt.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-258ef2d68aad> in <module>
# ----> 1 plt.__version__
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

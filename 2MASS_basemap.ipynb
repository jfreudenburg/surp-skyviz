# %%
import numpy as np
from astropy.io import fits
import fitsmap

hdu = fits.open('2MASS_catalogs/catalog/2mrs_1175_done.fits')

# %%
hdu[1].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                  161 /Number of bytes per row
# NAXIS2  =                43533 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                   29 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT The 2MASS Redshift Survey
# COMMENT Huchra et al., ApJS, in press
# COMMENT http://tdc-www.harvard.edu/2mrs/
# COMMENT catalog version 2.4, 2011 Dec 16
# COMMENT maintained by Lucas Macri, lmacri@tamu.edu
# COMMENT
# COMMENT Main catalog file
# COMMENT Please see README file for important information
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'TMID    '           / 2MASS ID
# TTYPE2  = 'RA      '           / RA  (J2000.0) in decimal degrees
# ...

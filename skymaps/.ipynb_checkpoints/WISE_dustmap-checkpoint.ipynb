# %%
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy.constants import c
from astropy.coordinates import Galactic

import numpy as np
import healpy as hp
import pandas as pd
import matplotlib.pyplot as plt

import projections
from mycmap import get_continuous_cmap
import mycmap

#data from https://faun.rc.fas.harvard.edu/ameisner/wssa/healpix.html

# %%
hdu = fits.open('map_data/WISE_dustmap.fits')
cat = hdu[0].data

# %%
dust = get_continuous_cmap(['#010e3d', 
                            '#2c0e4e', 
                            '#530848', 
                            '#73023d', 
                            '#8f0030', 
                            '#ab0023', 
                            '#c60016', 
                            '#e30007', 
                            '#ff0000'])

# %%
npix = cat.shape[0]
hpx_index = np.arange(npix)
dust_map = np.zeros(npix)
dust_map[hpx_index] = cat

# %%
hp.orthview(dust_map,cmap=mycmap.dust,norm='hist',coord=["G"])

# %%
projections.generate_projection_set(dust_map,
                                    size=4096,
                                    dname='WISE_galactic_4096',
                                    cmap=mycmap.dust,
                                    norm='hist',
                                    coord=["G"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/anaconda3/envs/surp-skyviz/lib/python3.9/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     499     try:
# --> 500         fh = fp.fileno()
#     501         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5e91622bf100> in <module>
# ----> 1 projections.generate_projection_set(dust_map,
#       2                                     size=4096,
#       3                                     dname='WISE_galactic_4096',
#       4                                     cmap=mycmap.h1,
#       5                                     norm='hist',
#
# ~/Projects/surp-skyviz/skymaps/projections.py in generate_projection_set(m, size, dname, coord, cmap, norm)
#     138             warnings.warn('Log normalization not yet implemented')
#     139
# --> 140         plt.imsave(fname=dirname+'/'+fnames[i][0]+'.png',
#     141                    arr=cmap(normalized(img[:,:size])),
#     142                    origin='lower',
#
# /opt/anaconda3/envs/surp-skyviz/lib/python3.9/site-packages/matplotlib/pyplot.py in imsave(fname, arr, **kwargs)
#    2249 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2250 def imsave(fname, arr, **kwargs):
# -> 2251     return matplotlib.image.imsave(fname, arr, **kwargs)
#    2252
#    2253
#
# /opt/anaconda3/envs/surp-skyviz/lib/python3.9/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# /opt/anaconda3/envs/surp-skyviz/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2170
#    2171         try:
# -> 2172             save_handler(self, fp, filename)
#    2173         finally:
#    2174             # do what we can to clean up
#
# /opt/anaconda3/envs/surp-skyviz/lib/python3.9/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1333         _write_multiple_frames(im, fp, chunk, rawmode)
#    1334     else:
# -> 1335         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1336
#    1337     if info:
#
# /opt/anaconda3/envs/surp-skyviz/lib/python3.9/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     512             else:
#     513                 while True:
# --> 514                     l, s, d = e.encode(bufsize)
#     515                     fp.write(d)
#     516                     if s:
#
# KeyboardInterrupt:
